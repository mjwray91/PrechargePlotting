# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilename()
print(file_path)
# Out:
# C:/Users/MichaelWray/OneDrive - northvolt.com/PAG 983/WO88/WO88/31-01-2021/1. 297-298.csv

# %%
df = pd.read_csv(file_path)
#df = df.replace(['???','????','?????','??????'],np.NaN)
#df = df.dropna(subset=['Gradename'])
#hist_Cap = df.Capacity1.hist(bins=100)
#hist_Cap.set_title('Capacity Histogram')
#hist_Cap.set_xlabel('Discharge Capacity at Production (mAh)')
#hist_Cap.set_ylabel('Frequency')

#Capacity_Histogram = hist_Cap.get_figure()
#Capacity_Histogram.savefig('Capacity Histogram')

# %%
df.describe()
# Out:
#          Voltage(V)    Current(A)  Capacity(Ah)    Energy(Wh)  Temperature1  \
# count  27973.000000  27973.000000  27973.000000  27973.000000  27973.000000
# mean       3.491180     18.441550     16.821522     60.086783     27.936986
# std        0.327968     13.277858     13.665058     50.738072      1.685451
# min        0.277500      0.000000      0.000000      0.000000     23.200000
# 25%        3.407500     11.301300      4.828200     15.163100     26.800000
# 50%        3.554700     11.302400     13.976700     49.389000     27.800000
# 75%        3.672100     33.902700     27.414000     97.720700     29.700000
# max        3.950000     37.608000     51.192900    192.781300     30.200000
#
#        CycleNo        StepNo  Pressure(Kpa)  EnvironmentTemp1(℃)  \
# count  27973.0  27973.000000   27973.000000              27973.0
# mean       1.0      4.840453     -66.509395                  0.0
# std        0.0      2.063563      13.231254                  0.0
# ...

# %%
df.plot(subplots=True, layout=(6,2), figsize=(15,20))
#df['index1'] = df.index # Give index a reference name
#Cell_production_order = df.plot.scatter(['index1'],'Capacity1') # plot capacity as scatter in order of reported conditioning data
#Cell_production_order.set_title('Cell Capacity Run-Chart from Conditioning Data')
#Cell_production_order.set_xlabel('Production Order')
#Cell_production_order.set_ylabel('Cell Capacity (mAh)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002CE9C8D2F10>,
# ...
#       dtype=object)
